# %%
import numpy as np
from sklearn.linear_model import LinearRegression as lr
import pandas as pd
import matplotlib.pyplot as mat

# %%
a = pd.read_csv("C:/Users/Rigam/Desktop/Rigam/bodyfat.csv")
print(a.head(12))
m,n= a.shape
a = np.array(a)
print(f"the size of the row is {m} \nthe size of the coloumn is : {n}")
height = a[:,4].reshape(-1,1)
weight = a[:,3].reshape(-1,1)
age = a[:,2].reshape(-1,1)
# for i in range(m):
#     height.append(a[i][4])
#     weight.append(a[i][3])
#     age.append(a[i][2])
# height = np.array(height).reshape(-1,1)
# weight = np.array(weight).reshape(-1,1)
# age = np.array(age)
X = np.hstack((height,weight))
model = lr()
model.fit(X,age)
# Out:
#     Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0    1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1    1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2    1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3    1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4    1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
# 5    1.0502     20.9   24  210.25   74.75  39.0  104.5     94.4  107.8   66.0
# 6    1.0549     19.2   26  181.00   69.75  36.4  105.1     90.7  100.3   58.4
# 7    1.0704     12.4   25  176.00   72.50  37.8   99.6     88.5   97.1   60.0
# 8    1.0900      4.1   25  191.00   74.00  38.1  100.9     82.5   99.9   62.9
# 9    1.0722     11.7   23  198.25   73.50  42.1   99.6     88.6  104.1   63.1
# 10   1.0830      7.1   26  186.25   74.50  38.5  101.5     83.6   98.2   59.7
# ...

# %%
mat.grid()
mat.scatter(height,age,color = "red")
mat.scatter(weight,age,color = "blue")
slope = model.coef_[0]
intercept = model.coef_
equation = f"y = {slope:.2f}x + {intercept:.2f}"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 6
#       4 slope = model.coef_[0]
#       5 intercept = model.coef_
# ----> 6 equation = f"y = {slope:.2f}x + {intercept:.2f}"
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %%
def pred(h,w):
    predicted_age= model.predict(np.array([[h,w]]))[0]
    print(f" the predicted age is as follows : {predicted_age}")
    mat.plot(age, predicted_age, color='red', label="Best Fit Line")

# %%
he = (int)(input("ENTER THE HEIGHT: "))
we = (int)(input("ENTER THE WEIGHT: "))

pred(he,we)
# Out:
#  the predicted age is as follows : [37.93890051]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 4
#       1 he = (int)(input("ENTER THE HEIGHT: "))
#       2 we = (int)(input("ENTER THE WEIGHT: "))
# ----> 4 pred(he,we)
#
# Cell In[39], line 4, in pred(h, w)
#       2 predicted_age= model.predict(np.array([[h,w]]))[0]
#       3 print(f" the predicted age is as follows : {predicted_age}")
# ----> 4 mat.plot(age, predicted_age, color='red', label="Best Fit Line")
#
# File c:\Users\Rigam\miniconda3\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
# ...
